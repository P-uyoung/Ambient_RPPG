# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
# for i in range(1,10,1):
#     folder = './VIPL_v2.zip.00' + str(i)
#     print(folder)

folder = 'D:\github.com\P-uyoung\Ambient_RPPG\VIPL_v2'
file_name = os.listdir(folder)
file_num = len(file_name)

HR = {}
fps = {}

for i in file_name:  # per person
    
    path = folder + '/' + i
    print(path)

    os.chdir(path)
    for csv in glob.glob("*.csv"):
        df = pd.read_csv(csv)

        
        for j in range(1,6,1):  # per video
            
            HR[str(i) +'/video'+str(j)] = df.iloc[0,j]
            fps[str(i) +'/video'+str(j)] = df.iloc[1,j]

            print(globals()['HR_{}'.format(i)])





    # for j in range(1, 6, 1):
    #     print(j)
    # print(path)
    # path=pd.read_csv(file_path)
# Out:
# D:\github.com\P-uyoung\Ambient_RPPG\VIPL_v2/7
# {'video1': 100.4, 'video2': 101.0, 'video3': 101.6, 'video4': 103.6, 'video5': 106.5}
# {'video1': 100.4, 'video2': 101.0, 'video3': 101.6, 'video4': 103.6, 'video5': 106.5}
# {'video1': 100.4, 'video2': 101.0, 'video3': 101.6, 'video4': 103.6, 'video5': 106.5}
# {'video1': 100.4, 'video2': 101.0, 'video3': 101.6, 'video4': 103.6, 'video5': 106.5}
# {'video1': 100.4, 'video2': 101.0, 'video3': 101.6, 'video4': 103.6, 'video5': 106.5}
# D:\github.com\P-uyoung\Ambient_RPPG\VIPL_v2/79
# D:\github.com\P-uyoung\Ambient_RPPG\VIPL_v2/8
# {'video1': 105.2, 'video2': 103.2, 'video3': 102.9, 'video4': 102.8, 'video5': 102.4}
# {'video1': 105.2, 'video2': 103.2, 'video3': 102.9, 'video4': 102.8, 'video5': 102.4}
# {'video1': 105.2, 'video2': 103.2, 'video3': 102.9, 'video4': 102.8, 'video5': 102.4}
# {'video1': 105.2, 'video2': 103.2, 'video3': 102.9, 'video4': 102.8, 'video5': 102.4}
# ...

# %%
fps
# Out:
# {'7/video1': 26.3,
#  '7/video2': 25.7,
#  '7/video3': 24.6,
#  '7/video4': 21.9,
#  '7/video5': 21.3,
#  '8/video1': 26.5,
#  '8/video2': 25.9,
#  '8/video3': 24.4,
#  '8/video4': 22.4,
#  '8/video5': 22.7,
#  '80/video1': 27.0,
#  '80/video2': 27.1,
#  '80/video3': 27.1,
#  '80/video4': 26.7,
#  '80/video5': 26.4,
#  '81/video1': 27.0,
#  '81/video2': 27.0,
#  '81/video3': 27.1,
#  '81/video4': 26.5,
#  '81/video5': 26.0,
#  '82/video1': 25.9,
#  '82/video2': 26.0,
#  '82/video3': 26.4,
#  '82/video4': 26.7,
#  '82/video5': 26.1,
#  '83/video1': 23.8,
#  '83/video2': 23.9,
#  '83/video3': 24.0,
#  '83/video4': 24.0,
#  '83/video5': 23.9,
#  '84/video1': 26.8,
#  '84/video2': 27.0,
#  '84/video3': 26.5,
#  '84/video4': 26.2,
#  '84/video5': 26.3,
#  '85/video1': 26.8,
#  '85/video2': 26.8,
#  '85/video3': 26.7,
#  '85/video4': 26.8,
#  '85/video5': 26.8,
#  '86/video1': 27.1,
#  '86/video2': 26.9,
#  '86/video3': 26.8,
#  '86/video4': 27.1,
#  '86/video5': 26.7,
# ...
