# %%
from google.colab import drive
drive.mount('/content/MyDrive')
# Out:
# Drive already mounted at /content/MyDrive; to attempt to forcibly remount, call drive.mount("/content/MyDrive", force_remount=True).

# %%
# %cd '/content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/ambient_rPPG/code'
# Out:
# /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/ambient_rPPG/code

# %%
import validation

# %%
# 전혀 자르지 않았을 때 오차
video_folder_path = r'/content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2'
validation.validate_VIPL_HR_V2(video_folder_path, test_num=10)
# Out:
# inference start : /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2/85/video1.mp4.avi
# 3/3 [==============================] - 5s 129ms/step
# inference done : 85/video1
# inference start : /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2/85/video2.mp4.avi
# 3/3 [==============================] - 0s 10ms/step
# inference done : 85/video2
# inference start : /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2/85/video3.mp4.avi
# 3/3 [==============================] - 0s 10ms/step
# inference done : 85/video3
# inference start : /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2/85/video4.mp4.avi
# 3/3 [==============================] - 0s 11ms/step
# inference done : 85/video4
# inference start : /content/MyDrive/MyDrive/Colab_Notebooks/GSDS_bootcamp_Ambient/project/VIPL_v2/85/video5.mp4.avi
# ...
